# %% [markdown]
# <a href="https://colab.research.google.com/github/YagyanshB/Stats-For-Data-Science/blob/main/Binomial_Distribution_Visualisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing the required libraries

import numpy as np
import pandas as pd
import math
import random
import matplotlib.pyplot as plt

# %%
# Binomial Distribution

n = 8
p = 0.16
N = 1000
X = np.random.binomial(n,p,N)

# %%
# Histogram of Binomial Distribution

counts, bins, ignored = plt.hist(X, 20, density = True, rwidth = 0.7, color = 'purple')
plt.title('Binomial Distribution with p = 0.16 and n = 8')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.show()
